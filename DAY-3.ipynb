# %%
 def is_palindrome(number):
    if number < 0:
        return False

    original = number
    reversed_num = 0

    while number > 0:
        digit = number % 10
        reversed_num = reversed_num * 10 + digit
        number //= 10

    return original == reversed_num

num = int(input("Enter a number: "))

if is_palindrome(num):
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Enter a number:  1234
# Not a palindrome

# %%
def fibonacci(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)

terms = int(input("Enter number of terms: "))

for i in range(terms):
    print(fibonacci(i),end=" ")
# Out:
# Enter number of terms:  9
# 0 1 1 2 3 5 8 13 21

# %%
def add(a, b):
 return a + b
def sub(a,b):
 return a-b
def multiply(a, b):
    return a * b
def divide(a, b):
    if b == 0:
        raise ValueError("Division by zero is not allowed.")
    return a / b
def average(a,b,c):
    return a+b+c/3
print(add(2,3))
print(sub(5,4))
print(multiply(3,6))
print(divide(6,3))
print(average(3,4,5))
# Out:
# 5
# 1
# 18
# 2.0
# 8.666666666666666

# %%
import random

def roll_dice(n):
    for i in range(n):
        print(random.randint(1, 6))

roll_dice(3)
# Out:
# 4
# 4
# 5

# %%
def quiz():
    score = 0

    questions = [
        ("What is the capital of India?", "B"),
        ("National animal of India?", "D"),
        ("How many states are there in India?", "A"),
        ("Who is known as the Father of the Nation?", "C"),
        ("Which is India's national bird?", "B")
    ]

    options = [
        ["A. Mumbai", "B. New Delhi", "C. Chennai", "D. Kolkata"],
        ["A. Lion", "B. Elephant", "C. Peacock", "D. Tiger"],
        ["A. 28", "B. 29", "C. 30", "D. 27"],
        ["A. Nehru", "B. Patel", "C. Mahatma Gandhi", "D. Bhagat Singh"],
        ["A. Sparrow", "B. Peacock", "C. Parrot", "D. Crow"]
    ]

    for i in range(5):
        print(f"\nQ{i+1}. {questions[i][0]}")

        for option in options[i]:
            print(option)

        answer = input("Enter your answer (A/B/C/D): ").upper()

        if answer == questions[i][1]:
            print("Correct!")
            score += 1
        else:
            print("Wrong!")

    print("\nYour Score:", score, "/5")

quiz()
# Out:
# Q1. What is the capital of India?
# A. Mumbai
# B. New Delhi
# C. Chennai
# D. Kolkata
# Enter your answer (A/B/C/D):  b
# Correct!
#
# Q2. National animal of India?
# A. Lion
# B. Elephant
# C. Peacock
# D. Tiger
# Enter your answer (A/B/C/D):  c
# Wrong!
#
# Q3. How many states are there in India?
# A. 28
# B. 29
# C. 30
# D. 27
# Enter your answer (A/B/C/D):  b
# Wrong!
#
# Q4. Who is known as the Father of the Nation?
# A. Nehru
# B. Patel
# C. Mahatma Gandhi
# D. Bhagat Singh
# Enter your answer (A/B/C/D):  c
# Correct!
#
# Q5. Which is India's national bird?
# A. Sparrow
# B. Peacock
# C. Parrot
# D. Crow
# Enter your answer (A/B/C/D):  b
# Correct!
#
# Your Score: 3 /5

# %%
import random
import string

def generate_password(length=12):
    characters = string.ascii_letters + string.digits
    return ''.join(random.choice(characters) for _ in range(length))

print("Password:", generate_password(12))
# Out:
# Password: k8dI8AebfoAs

# %%
def factorial_iterative(n):
    if n < 0:
        return "Factorial not defined for negative numbers"

    result = 1
    for i in range(1, n + 1):
        result *= i

    return result
factorial_iterative(4)
def factorial_recursive(n):
    if n < 0:
        return "Factorial not defined for negative numbers"
    elif n == 0 or n == 1:
        return 1
    else:
        return n * factorial_recursive(n - 1)
print(factorial_iterative(5))
print(factorial_iterative(7))
# Out:
# 120
# 5040
